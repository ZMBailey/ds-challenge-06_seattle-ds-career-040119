# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %%
# Create subplots
fig, axs = plt.subplots(1, 1, figsize=(10, 8))

# Create some fake data with a normal distribution
normal_dist = stats.norm(loc=0, scale=1)
fake_y = normal_dist.rvs(1000)  

x_label = 'Minutes'
y_label = 'Count'
hist_title = 'Student On-Time Performance'

# Plot the data from the normal distribution
# ax = axs[0]
# ax.hist(fake_y, bins=20)  # Let's try something in between
# ax.set_xlabel(x_label)
# ax.set_ylabel(y_label)
# ax.set_title("Normal Distribution")

# Based on previous histograms, an exponential distribution seems more likely to generate similar data.

# Create some fake data with an exponential distribution
# adjust the loc to -1 to get x axis in the right range, and scale to 15 to keep the distribution similar
exponential_dist = stats.expon(loc=-1, scale=15)
# adjust the input number to get similar data counts to the original dataset.
fake_y = exponential_dist.rvs(180)  

# Plot the data from the exponential distribution
#ax = axs[1]
axs.hist(-fake_y, bins=20)  # Let's try something in between
axs.set_xlabel(x_label)
axs.set_ylabel(y_label)
axs.set_title("Expenential Distribution")

# Show the plots
plt.tight_layout()
plt.show()
